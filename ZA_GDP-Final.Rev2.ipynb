# %% [markdown]
# # <font color='maroon'>Assessment</font>

# %% [markdown]
# Gross domestic product, or GDP, indicates how well an economy is performing.
# GDP is the total market value of everything produced by all the people and companies in the country over a given period.
# Many features determine this total value. Let's look at GDP data from South Africa between 1960 and 2017. In this notebook, you will be exploring and visualizing the dataset to communicate trends/patterns that show changes in the South African economy during this period. We've provided you with prompts for you to respond to. Uncomment and run the code where provided. Otherwise, add to and write the code necessary to come up with responses to the code.

# %% [markdown]
# ### Question 1(a)
# The data you will use is contained in a file called `API_ZAF_DS2_en_csv_v2.csv`.
#
# Open the data file and study the columns. The file contains many indicators and indicator codes for sections that contribute to GDP. Consider the following indicators. Create a dataframe to store values for these indicators between the years 2000 and 2017. Hint: If you use the indicator codes as indexes, set them as such.
#
#     BX.GSR.TRVL.ZS
#     BN.TRF.KOGT.CD
#     BM.TRF.PWKR.CD.DT
#     BG.GSR.NFSV.GD.ZS
#     AG.YLD.CREL.KG

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
from pandas.tools import plotting
import seaborn as sns
import scipy.stats as stats
#import plotly
#plotly.offline.init_notebook_mode(connected=True)
#import plotly.offline as py

# %%
# %matplotlib inline

# %%
data = pd.read_csv('API_ZAF_DS2_en_csv_v2.csv', 
                    skiprows=3, 
                    header=0,
                    sep=',',
                    na_values='0')

# %%
data
# Out:
#       Country Name Country Code  \
# 0     South Africa          ZAF
# 1     South Africa          ZAF
# 2     South Africa          ZAF
# 3     South Africa          ZAF
# 4     South Africa          ZAF
# 5     South Africa          ZAF
# 6     South Africa          ZAF
# 7     South Africa          ZAF
# 8     South Africa          ZAF
# 9     South Africa          ZAF
# 10    South Africa          ZAF
# 11    South Africa          ZAF
# 12    South Africa          ZAF
# 13    South Africa          ZAF
# 14    South Africa          ZAF
# 15    South Africa          ZAF
# 16    South Africa          ZAF
# 17    South Africa          ZAF
# 18    South Africa          ZAF
# 19    South Africa          ZAF
# 20    South Africa          ZAF
# 21    South Africa          ZAF
# 22    South Africa          ZAF
# 23    South Africa          ZAF
# 24    South Africa          ZAF
# 25    South Africa          ZAF
# 26    South Africa          ZAF
# 27    South Africa          ZAF
# ...

# %%
print('Size of raw csv file:',data.size)
print('Sahe of the raw csv file',data.shape)
print('\n','Raw csv info \n')
data.info()
# Out:
# Size of raw csv file: 99225
# Sahe of the raw csv file (1575, 63)
#
#  Raw csv info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Data columns (total 63 columns):
# Country Name      1575 non-null object
# Country Code      1575 non-null object
# Indicator Name    1575 non-null object
# Indicator Code    1575 non-null object
# 1960              293 non-null float64
# 1961              320 non-null float64
# 1962              328 non-null float64
# 1963              331 non-null float64
# 1964              331 non-null float64
# 1965              339 non-null float64
# 1966              343 non-null float64
# 1967              339 non-null float64
# 1968              343 non-null float64
# 1969              337 non-null float64
# 1970              426 non-null float64
# 1971              407 non-null float64
# 1972              456 non-null float64
# 1973              453 non-null float64
# 1974              465 non-null float64
# ...

# %%
data10 = data.loc[data['Indicator Code'] == 'BX.GSR.TRVL.ZS', '2000':'2017']
data11 = data.loc[data['Indicator Code'] == 'BN.TRF.KOGT.CD', '2000':'2017']
data12 = data.loc[data['Indicator Code'] == 'BM.TRF.PWKR.CD.DT', '2000':'2017']
data13 = data.loc[data['Indicator Code'] == 'BG.GSR.NFSV.GD.ZS', '2000':'2017']
data14 = data.loc[data['Indicator Code'] == 'AG.YLD.CREL.KG', '2000':'2017']
data_ap = data10.append([data10, data11, data12, data13, data14])
data_ap.apply(np.round)
# Out:
#             2000         2001         2002         2003         2004  \
# 574         53.0         53.0         57.0         66.0         64.0
# 574         53.0         53.0         57.0         66.0         64.0
# 588          NaN          NaN  -14989200.0   43567095.0   52406686.0
# 600  614277482.0  520760001.0  505532299.0  705751528.0  934598614.0
# 614          8.0          8.0          9.0         10.0          9.0
# 615       2762.0       2423.0       2772.0       2537.0       2778.0
#
#              2005          2006          2007          2008          2009  \
# 574  6.400000e+01  6.200000e+01  5.900000e+01  5.700000e+01  5.800000e+01
# 574  6.400000e+01  6.200000e+01  5.900000e+01  5.700000e+01  5.800000e+01
# 588  3.043985e+07  3.023823e+07  2.797462e+07  2.549414e+07  2.572819e+07
# 600  1.041844e+09  1.055263e+09  1.172717e+09  1.118933e+09  1.143855e+09
# 614  9.000000e+00  1.000000e+01  1.000000e+01  1.100000e+01  1.000000e+01
# ...

# %% [markdown]
# ### Question 1(b)
# Give summary statistics of the data.

# %%
data_ap = data_ap.dropna(thresh=8)
data_ap
# Out:
#              2000          2001          2002          2003          2004  \
# 574  5.304698e+01  5.302119e+01  5.719602e+01  6.596572e+01  6.385462e+01
# 574  5.304698e+01  5.302119e+01  5.719602e+01  6.596572e+01  6.385462e+01
# 588           NaN           NaN -1.498920e+07  4.356710e+07  5.240669e+07
# 600  6.142775e+08  5.207600e+08  5.055323e+08  7.057515e+08  9.345986e+08
# 614  7.990345e+00  8.295649e+00  9.170201e+00  9.529789e+00  8.966245e+00
# 615  2.762200e+03  2.423000e+03  2.771800e+03  2.536800e+03  2.777600e+03
#
#              2005          2006          2007          2008          2009  \
# 574  6.353995e+01  6.217756e+01  5.915778e+01  5.683486e+01  5.775726e+01
# 574  6.353995e+01  6.217756e+01  5.915778e+01  5.683486e+01  5.775726e+01
# 588  3.043985e+07  3.023823e+07  2.797462e+07  2.549414e+07  2.572819e+07
# 600  1.041844e+09  1.055263e+09  1.172717e+09  1.118933e+09  1.143855e+09
# 614  9.306290e+00  1.000832e+01  1.039523e+01  1.080158e+01  9.621928e+00
# ...

# %%
data_ap.shape
# Out:
# (6, 18)

# %%
data_ap.describe().apply(np.round)
# Out:
#               2000         2001         2002         2003         2004  \
# count          5.0          5.0          6.0          6.0          6.0
# mean   122856072.0  104152508.0   81757666.0  124886884.0  164501369.0
# std    274712920.0  232890669.0  207692891.0  285097495.0  377850983.0
# min            8.0          8.0  -14989200.0         10.0          9.0
# 25%           53.0         53.0         21.0         66.0         64.0
# 50%           53.0         53.0         57.0       1301.0       1421.0
# 75%         2762.0       2423.0       2093.0   32675956.0   39305709.0
# max    614277482.0  520760001.0  505532299.0  705751528.0  934598614.0
#
#                2005          2006          2007          2008          2009  \
# count  6.000000e+00  6.000000e+00  6.000000e+00  6.000000e+00  6.000000e+00
# mean   1.787146e+08  1.809175e+08  2.001157e+08  1.907386e+08  1.949313e+08
# std    4.230207e+08  4.285109e+08  4.766067e+08  4.548349e+08  4.649897e+08
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
data_ap.boxplot()

# %%
fig, ax = plt.subplots(figsize=(15,10))
data_ap.mean().plot(title ="2000 to 2017 of the 5 selected Indicators")
ax.set_xlabel("Data set", fontsize=12)
ax.set_ylabel("Growth", fontsize=12)
# Out:
# Text(0,0.5,'Growth')

# %% [markdown]
# ## Answer to 1b
# ### Conclusion:
# From my understanding of the data we can see a steady climb / growth in the South African economy up till 2007. At this point in time we had the great financial crash worldwide and so we can see from the data again how the South African economy declined. We do see a blimp in this time line around 2010 were South Africa hosted the soccer world cup with boosted us a little but since then we have remained in a technical recession.

# %% [markdown]
# ### Question 2(a)
# Determine the mean GDP for each year given in the file.

# %% [markdown]
# #### Assumption
# 'BG.GSR.NFSV.GD.ZS' was selected as is is the only dataset with 'GDP' in the tytle

# %%
dataGDP = data.loc[data['Indicator Code'] == 'BG.GSR.NFSV.GD.ZS', '2000':'2017'].round(3).mean(axis=0)
dataGDP
# Out:
# 2000     7.990
# 2001     8.296
# 2002     9.170
# 2003     9.530
# 2004     8.966
# 2005     9.306
# 2006    10.008
# 2007    10.395
# 2008    10.802
# 2009     9.622
# 2010     9.500
# 2011     9.166
# 2012     9.223
# 2013     9.506
# 2014     9.647
# 2015     9.629
# 2016     9.922
# 2017       NaN
# dtype: float64

# %% [markdown]
# ## Answer to 2(a)
# ### Conclusion
# Again, looking at the data and plot we can see that as pointed out in answer 1(b) that the GDP growth was steady from 2000 to 2007. Then we had the great worldwide financial crash witch effected South Africa and the GDP dropped. Because SA hosted the Soccer World Cup in 2010 the building of stadiums and other facilities artificially stimulated our GDP growth. we also had an influx of tourists to SA over this period. but after this SA joined the rest of the world again in terms of the GDP number falling and SA has since remained in a technical recession.

# %% [markdown]
# ### Question 2(b)
# Plot the mean GDP per year using a line graph. What trend do you observe in the data?

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = data23 = data.loc[data['Indicator Code'] == 'BG.GSR.NFSV.GD.ZS', '2000':'2017'].mean().plot(title ="2000 to 2017 GDP (mean view)", legend=True, fontsize=12)
ax.set_xlabel("Data set", fontsize=12)
ax.set_ylabel("Growth", fontsize=12)
plt.show()

# %% [markdown]
# ## Answer to 2(b)
# ### Conclusion
# The GDP growth was steady from 2000 to 2007. Then we had the great worldwide financial crash witch effected South Africa and the GDP dropped. Because SA hosted the Soccer World Cup in 2010 the building of stadiums and other facilities artificially stimulated our GDP growth. we also had an influx of tourists to SA over this period. but after this SA joined the rest of the world again in terms of the GDP number falling and SA has since remained in a technical recession.

# %% [markdown]
# ### Question 3
# Energy is quite an important sector the economy. Let's look at how much the energy industries contribute to GDP. Compare the mean contribution to GDP by the electricity, renewable energy and fossil fuels over the years. The `Indicator` column can assist you with this. Identify any other energy sectors.

# %%
# your asnwer

# %% [markdown]
# ### Question 4(a)
# Between 1960 to 1969 some sectors had no data. Use a bar graph and show how these sectors have progressed since 1970.

# %%
data20 = data.loc[data['Indicator Code'] == 'BX.GSR.TRVL.ZS', '1970':'2017']
data21 = data.loc[data['Indicator Code'] == 'BN.TRF.KOGT.CD', '1970':'2017']
data22 = data.loc[data['Indicator Code'] == 'BM.TRF.PWKR.CD.DT', '1970':'2017']
data23 = data.loc[data['Indicator Code'] == 'BG.GSR.NFSV.GD.ZS', '1970':'2017']
data24 = data.loc[data['Indicator Code'] == 'AG.YLD.CREL.KG', '1970':'2017']
data_ap_2 = data20.append([data20, data21, data22, data23, data24])
data_ap_2.apply(np.round)
# Out:
#             1970         1971         1972         1973         1974  \
# 574         56.0         59.0         56.0         58.0         59.0
# 574         56.0         59.0         56.0         58.0         59.0
# 588          NaN          NaN          NaN          NaN          NaN
# 600  236599899.0  283822327.0  279514374.0  423839386.0  566159302.0
# 614          8.0          8.0          8.0          7.0          7.0
# 615       1187.0       1498.0       1594.0       1008.0       1876.0
#
#             1975         1976         1977         1978         1979  ...   \
# 574         61.0         58.0         58.0         56.0         55.0  ...
# 574         61.0         58.0         58.0         56.0         55.0  ...
# 588          NaN          NaN          NaN          NaN          NaN  ...
# 600  666929443.0  576150024.0  629049988.0  696900024.0  805829651.0  ...
# 614          9.0          8.0          8.0          8.0          8.0  ...
# ...

# %%
ax = data_ap_2.plot.barh(title ="1970 to 2017 of the 5 selected Indicators",figsize=(15,14) , legend=True, fontsize=12)
ax.set_xlabel("Data set", fontsize=12)
ax.set_ylabel("Growth", fontsize=12)
plt.show()

# %% [markdown]
# ### Answer 4(a)
# You can see of the 5 Indicators have grown over the time period from 1970 to 2017

# %% [markdown]
# ### Question4(b)
# Discuss how you think these missing values or no information data should be handled. When is it okay to replace missing values with the mean or the median? Plot a graph to show how the mean GDP is affected when missing values are replaced with the mean and the median. Do these plots differ? Do these plots differ from the plot in question 2(b)?

# %% [markdown]
# ### Answer 4(b)
#
# - There is no data missing from GDP BG.GSR.NFSV.GD.ZS data set from the years 1970 to 2017.
# - Looking at the two graphs below, one with mean value applied and the other with median value applied you don’t really see a difference.
# - Comparing the 2(b) and 4(b) dataset you can see the dip in the GDP growth from 2000 - 2017 reoccur throughout the time period. I am not sure about the previous smaller growths in the GDP data after a large crash of the economy.

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = data23 = data.loc[data['Indicator Code'] == 'BG.GSR.NFSV.GD.ZS', '1970':'2017'].mean().plot(title ="1970 to 2017 GDP (mean view)", legend=True, fontsize=12)
ax.set_xlabel("Data set", fontsize=12)
ax.set_ylabel("Growth", fontsize=12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = data23 = data.loc[data['Indicator Code'] == 'BG.GSR.NFSV.GD.ZS', '1970':'2017'].median().plot(title ="1970 to 2017 GDP (median view)", legend=True, fontsize=12)
ax.set_xlabel("Data set", fontsize=12)
ax.set_ylabel("Growth", fontsize=12)
plt.show()

# %% [markdown]
# ### Question 5
# Which sectors of the economy have contributed the most to GDP. Perhaps consider grouping similar sectors into one group and determine which group has the biggest value contributed to GDP over a certain period.
